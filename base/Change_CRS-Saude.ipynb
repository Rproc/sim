# %%
import pandas as pd
from pyproj import Proj, transform
import fiona
from fiona.crs import from_epsg
import logging
import sys


# outProj = Proj(init='epsg:3857')
# inProj = Proj(init='epsg:4326') # It is equal to WSG

# %%
shape = fiona.open("Mapas_sim/social/saude_estabelecimentos_cnesPoint.shp")
print (shape.schema)
# Out:
# {'properties': OrderedDict([('Município', 'str:254'), ('Código_CNE', 'str:254'), ('Razão_Soci', 'str:254'), ('Estabeleci', 'str:254'), ('CNPJ_Mante', 'str:254'), ('Endereço', 'str:254'), ('Telefone', 'str:254'), ('Email_ou_F', 'str:254'), ('Tipo', 'str:254'), ('Gestão', 'str:254')]), 'geometry': 'Point'}

# %%
shape[0]
# Out:
# {'type': 'Feature',
#  'id': '0',
#  'properties': OrderedDict([('Município', 'BELFORD ROXO'),
#               ('Código_CNE', '3300453425797'),
#               ('Razão_Soci',
#                'AMB DO CENTRO MUN DE REF EM EDUC ESP ALBERT SABI'),
#               ('Estabeleci', 'AMBULATORIO ALBERT SABIN'),
#               ('CNPJ_Mante', '39485438000223'),
#               ('Endereço',
#                'RUA CELI, S/N - NOVA PIAM, BELFORD ROXO - RJ, 26115-000'),
#               ('Telefone', '(21)26620566'),
#               ('Email_ou_F', None),
#               ('Tipo', 'CLINICA/CENTRO DE ESPECIALIDADE'),
#               ('Gestão', 'MUNICIPAL')]),
#  'geometry': {'type': 'Point',
#   'coordinates': (-43.39518410000001, -22.741947699999997)}}

# %%
for i in range(0, len(shape)):
    print((shape[i]['geometry']['type']))
# Out:
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point
# Point

# %%
# Transformar escala lag, long em Metros no globo achatado

# salvando o esquema e pegando a projecao de entrada
sink_schema = shape.schema.copy()
p_in = Proj(shape.crs)

# definindo um novo shape de saida, no mesmo local do shape atual com a projeção mudada
with fiona.open(
        'saude_metros.shp', 'w',
        crs=from_epsg(3857),
        driver=shape.driver,
        schema=sink_schema,
        ) as sink:

    p_out = Proj(sink.crs)

    # fazendo apenas para o Chico Mendes (esse arquivo tem Polygon e MultiPolygon)
    # nesse caso, se fizesse para o arquivo todo, nao seria contemplado alguns shapes
    for f in shape:
        try:
            # verifica se eh da estrutura poligono
            assert f['geometry']['type'] == "Point"
            new_coords = []
            l = []
            # para todas as coordenadas do poligono
            for j in f['geometry']['coordinates']:
                l.append(j)

            x2, y2 = transform(p_in, p_out, l[0], l[1]) #transforma
            f['geometry']['coordinates'] = [x2, y2]
            l = []
            sink.write(f)


        except Exception:
        # Writing uncleanable features to a different shapefile
        # is another option.
            logging.exception("Error transforming feature %s:", f['id'])
# Out:
# /opt/anaconda/lib/python3.7/site-packages/pyproj/crs.py:77: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method.
#   return _prepare_from_string(" ".join(pjargs))
# /opt/anaconda/lib/python3.7/site-packages/pyproj/crs.py:77: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method.
#   return _prepare_from_string(" ".join(pjargs))

# %%
shape2 = fiona.open("saude_metros.shp")
print (shape2.schema)
# Out:
# {'properties': OrderedDict([('Município', 'str:254'), ('Código_CNE', 'str:254'), ('Razão_Soci', 'str:254'), ('Estabeleci', 'str:254'), ('CNPJ_Mante', 'str:254'), ('Endereço', 'str:254'), ('Telefone', 'str:254'), ('Email_ou_F', 'str:254'), ('Tipo', 'str:254'), ('Gestão', 'str:254')]), 'geometry': 'Point'}

# %%
shape[0]
# Out:
# {'type': 'Feature',
#  'id': '0',
#  'properties': OrderedDict([('Município', 'BELFORD ROXO'),
#               ('Código_CNE', '3300453425797'),
#               ('Razão_Soci',
#                'AMB DO CENTRO MUN DE REF EM EDUC ESP ALBERT SABI'),
#               ('Estabeleci', 'AMBULATORIO ALBERT SABIN'),
#               ('CNPJ_Mante', '39485438000223'),
#               ('Endereço',
#                'RUA CELI, S/N - NOVA PIAM, BELFORD ROXO - RJ, 26115-000'),
#               ('Telefone', '(21)26620566'),
#               ('Email_ou_F', None),
#               ('Tipo', 'CLINICA/CENTRO DE ESPECIALIDADE'),
#               ('Gestão', 'MUNICIPAL')]),
#  'geometry': {'type': 'Point',
#   'coordinates': (-43.39518410000001, -22.741947699999997)}}

# %%
shape2[0]
# Out:
# {'type': 'Feature',
#  'id': '0',
#  'properties': OrderedDict([('Município', 'BELFORD ROXO'),
#               ('Código_CNE', '3300453425797'),
#               ('Razão_Soci',
#                'AMB DO CENTRO MUN DE REF EM EDUC ESP ALBERT SABI'),
#               ('Estabeleci', 'AMBULATORIO ALBERT SABIN'),
#               ('CNPJ_Mante', '39485438000223'),
#               ('Endereço',
#                'RUA CELI, S/N - NOVA PIAM, BELFORD ROXO - RJ, 26115-000'),
#               ('Telefone', '(21)26620566'),
#               ('Email_ou_F', None),
#               ('Tipo', 'CLINICA/CENTRO DE ESPECIALIDADE'),
#               ('Gestão', 'MUNICIPAL')]),
#  'geometry': {'type': 'Point',
#   'coordinates': (-4830729.796892363, -2600841.2643439258)}}

# %%
# Transformar escala lag, long em Metros no globo achatado

# salvando o esquema e pegando a projecao de entrada
sink_schema = shape2.schema.copy()
p_in = Proj(shape2.crs)

# definindo um novo shape de saida, no mesmo local do shape atual com a projeção mudada
with fiona.open(
        'saude_metros2.shp', 'w',
        crs=from_epsg(4326),
        driver=shape2.driver,
        schema=sink_schema,
        ) as sink:

    p_out = Proj(sink.crs)

    # fazendo apenas para o Chico Mendes (esse arquivo tem Polygon e MultiPolygon)
    # nesse caso, se fizesse para o arquivo todo, nao seria contemplado alguns shapes
    f = shape2[0]
    try:
        # verifica se eh da estrutura poligono
        assert f['geometry']['type'] == "Point"
        new_coords = []
        l = []
        # para todas as coordenadas do poligono
        for j in f['geometry']['coordinates']:
            l.append(j)

        x2, y2 = transform(p_in, p_out, l[0], l[1]) #transforma
        f['geometry']['coordinates'] = [x2, y2]
        l = []
        sink.write(f)


    except Exception:
    # Writing uncleanable features to a different shapefile
    # is another option.
        logging.exception("Error transforming feature %s:", f['id'])
# Out:
# /opt/anaconda/lib/python3.7/site-packages/pyproj/crs.py:77: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method.
#   return _prepare_from_string(" ".join(pjargs))
# /opt/anaconda/lib/python3.7/site-packages/pyproj/crs.py:77: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method.
#   return _prepare_from_string(" ".join(pjargs))

# %%
shape3 = fiona.open("saude_metros2.shp")
print (shape3.schema)
# Out:
# {'properties': OrderedDict([('Município', 'str:254'), ('Código_CNE', 'str:254'), ('Razão_Soci', 'str:254'), ('Estabeleci', 'str:254'), ('CNPJ_Mante', 'str:254'), ('Endereço', 'str:254'), ('Telefone', 'str:254'), ('Email_ou_F', 'str:254'), ('Tipo', 'str:254'), ('Gestão', 'str:254')]), 'geometry': 'Point'}

# %%
print(shape3[0])
# Out:
# {'type': 'Feature', 'id': '0', 'properties': OrderedDict([('Município', 'BELFORD ROXO'), ('Código_CNE', '3300453425797'), ('Razão_Soci', 'AMB DO CENTRO MUN DE REF EM EDUC ESP ALBERT SABI'), ('Estabeleci', 'AMBULATORIO ALBERT SABIN'), ('CNPJ_Mante', '39485438000223'), ('Endereço', 'RUA CELI, S/N - NOVA PIAM, BELFORD ROXO - RJ, 26115-000'), ('Telefone', '(21)26620566'), ('Email_ou_F', None), ('Tipo', 'CLINICA/CENTRO DE ESPECIALIDADE'), ('Gestão', 'MUNICIPAL')]), 'geometry': {'type': 'Point', 'coordinates': (-43.3951841, -22.741947699999994)}}
